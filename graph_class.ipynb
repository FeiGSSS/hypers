# %%
from torch_geometric.datasets import TUDataset
from torch_geometric.utils import to_networkx

import matplotlib.pyplot as plt
import networkx as nx

from torch_geometric.data import Data

# %%
dataset = TUDataset("./data/TU", name="MUTAG")
print(dataset)
# g = to_networkx(dataset[1])
# nx.draw_kamada_kawai(g, node_size=10)
# Out:
# MUTAG(188)

# %%
dataset.data.x is None
# Out:
# False

# %%
data = dataset[0]

# %%
data
# Out:
# Data(edge_index=[2, 38], x=[17, 7], edge_attr=[38, 4], y=[1])

# %%
from torch_geometric.utils import k_hop_subgraph

# %%
subset, edge_index, mapping, edge_mask = k_hop_subgraph(4, 1, 
                                                        data.edge_index, 
                                                        relabel_nodes=True)
subgraph = Data(edge_index=edge_index)
g = to_networkx(subgraph)
nx.draw_kamada_kawai(g, node_size=10)
